# %%
import numpy as np
import pandas as pd
import pyarrow.parquet as pq
import seaborn as sns
import matplotlib.pyplot as plt

import sys

from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import sklearn as sk
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_squared_error
from sklearn.compose import ColumnTransformer
import statsmodels.api as sm

import datetime

# %%
# podaci_s = pd.read_parquet("C:/Users/vvrhovec/Veronika/kodovi/dataParquet_s.parquet")
# print(podaci_s)

# %%
# podaci_s['day_of_week'] = podaci_s.index.get_level_values('datum').day_name()
# n = podaci_s.shape[0]
# nule = [0]*n

# podaci_s['Monday'] = nule
# podaci_s['Tuesday'] = nule
# podaci_s['Wednesday'] = nule
# podaci_s['Thursday'] = nule
# podaci_s['Friday'] = nule
# podaci_s['Saturday'] = nule
# podaci_s['Sunday'] = nule

#for art, new_df in podaci_s.groupby(level=0):
 #   for index, row in new_df.iterrows():
  #      dan=row['day_of_week']
   #     podaci_s.loc[(row.name[0],row.name[1].date()),dan] = 1
    
# podaci_s['Vikend'] = np.where(podaci_s['day_of_week'] == "Saturday",1,np.where(podaci_s['day_of_week'] == "Sunday",1,0))

# podaci_sredjeni = podaci_s.rename(columns={"Vikend": "Weekend"})

# podaci_sredjeni=podaci_sredjeni.drop('day_of_week',axis=1)

# podaci_sredjeni.sort_index(inplace=True)

# dataParquet_sredjeni = podaci_sredjeni.to_parquet('dataParquet_sredjeni.parquet')

#def scaling_columns_seperately(self_train,self_test,col):
#    if self.index.min() <= parse("2018-01-01"):
 #       aux_df = self[col]
  #      std_scaler.fit(aux_df.values.reshape(-1,1))
   #     aux_df = std_scaler.transform(self[col].values.reshape(-1,1))
    #    self[col] = aux_df
    #else:
     #   aux_df = self[col]
      #  aux_df = std_scaler.transform(self[col].values.reshape(-1,1))
       # self[col] = aux_df
        
        
# X=X.rename_axis(index={'art': 'item','datum':'date'})
# X=X.rename(columns={"redna_cena":"regular_price", "akcijska_cena":"discounted_price","n_trgovin":"number_of_stores","kol":"amount"})

#for row, column in X_38_train.iterrows():
 #   print(row,column)
  #  print()

#def removing_outliers(self,col):
 #   print(col)
  #  upper_lim = self[col].quantile(.95)
   # lower_lim = self[col].quantile(.05)
    #self = data.loc[(df[column] > upper_lim),column]
   # print(upper_lim)
   # print(lower_lim)
   # for row, column in self.iterrows(): 
        #if self[row][col] < upper_lim or self[row][col] > lower_lim:
    #     print (column, self[row][col])
    
    # for column in X_38_train:                               
    # removing_outliers(X_38_test,column)

# %%
X = pd.read_parquet("C:/Users/vvrhovec/Veronika/kodovi/dataParquet_sredjeni.parquet")
# Out:
# C:\Users\vvrhovec\AppData\Local\Continuum\miniconda3\envs\okolina\lib\site-packages\pyarrow\pandas_compat.py:708: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels = getattr(columns, 'labels', None) or [
# C:\Users\vvrhovec\AppData\Local\Continuum\miniconda3\envs\okolina\lib\site-packages\pyarrow\pandas_compat.py:735: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   return pd.MultiIndex(levels=new_levels, labels=labels, names=columns.names)
# C:\Users\vvrhovec\AppData\Local\Continuum\miniconda3\envs\okolina\lib\site-packages\pyarrow\pandas_compat.py:752: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels, = index.labels

# %%
# X_38_train.to_parquet('X_38_train.parquet')
# X_38_test.to_parquet('X_38_test.parquet')

# %%
print(X)
# Out:
#                 redna_cena  akcijska_cena  n_trgovin    kol  Monday  Tuesday  \
# art datum
# 38  2016-01-02       0.100          0.100        439  769.0       0        0
#     2016-01-03       0.100          0.100        436  100.0       0        0
#     2016-01-04       0.100          0.100        441  305.0       1        0
X_38_te = X_38.loc[X_38.index.get_level_values('datum') > '2018-01-01']
X_38_test = X_38_te.drop('kol',axis=1)

y_38_train = X_38_tr['kol']
y_38_test = X_38_te['kol']

# %%
print (X_38_train.shape, y_38_train.shape)
print (X_38_test.shape, y_38_test.shape)
# Out:
# (685, 11) (685,)
# (130, 11) (130,)

# %% [markdown]
# ### Preprocesiranje **TRAINING** podataka

# %%
#std_scaler.fit(X_38_train)   #skalirat ćemo po svakom stupcu zasebno
#X_38_train_scaled = std_scaler.transform(X_38_train)

# %%
pomocna_train = X_38_train['redna_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_38_train['redna_cena'].values.reshape(-1,1))  
X_38_train['redna_cena'] = pomocna_train

pomocna_test = X_38_test['redna_cena']
pomocna_test = std_scaler.transform(X_38_test['redna_cena'].values.reshape(-1,1))  
X_38_test['redna_cena'] = pomocna_test

pomocna_train = X_38_train['akcijska_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_38_train['akcijska_cena'].values.reshape(-1,1))  
X_38_train['akcijska_cena'] = pomocna_train

pomocna_test = X_38_test['akcijska_cena']
pomocna_test = std_scaler.transform(X_38_test['akcijska_cena'].values.reshape(-1,1))  
X_38_test['akcijska_cena'] = pomocna_test

pomocna_train = X_38_train['n_trgovin']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_38_train['n_trgovin'].values.reshape(-1,1))  
X_38_train['n_trgovin'] = pomocna_train

pomocna_test = X_38_test['n_trgovin']
pomocna_test = std_scaler.transform(X_38_test['n_trgovin'].values.reshape(-1,1))  
X_38_test['n_trgovin'] = pomocna_test

pomocna_train = X_38_train['Monday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_38_train['Monday'].values.reshape(-1,1))  
X_38_train['Monday'] = pomocna_train

pomocna_test = X_38_test['Monday']
pomocna_test = std_scaler.transform(X_38_test['Monday'].values.reshape(-1,1))  
X_38_test['Monday'] = pomocna_test

pomocna_train = X_38_train['Tuesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_38_train['Tuesday'].values.reshape(-1,1))  
X_38_train['Tuesday'] = pomocna_train

pomocna_test = X_38_test['Tuesday']
pomocna_test = std_scaler.transform(X_38_test['Tuesday'].values.reshape(-1,1))  
X_38_test['Tuesday'] = pomocna_test

pomocna_train = X_38_train['Wednesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_38_train['Wednesday'].values.reshape(-1,1))  
X_38_train['Wednesday'] = pomocna_train

pomocna_test = X_38_test['Wednesday']
pomocna_test = std_scaler.transform(X_38_test['Wednesday'].values.reshape(-1,1))  
X_38_test['Wednesday'] = pomocna_test

pomocna_train = X_38_train['Thursday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_38_train['Thursday'].values.reshape(-1,1))  
X_38_train['Thursday'] = pomocna_train

pomocna_test = X_38_test['Thursday']
pomocna_test = std_scaler.transform(X_38_test['Thursday'].values.reshape(-1,1))  
X_38_test['Thursday'] = pomocna_test

pomocna_train = X_38_train['Friday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_38_train['Friday'].values.reshape(-1,1))  
X_38_train['Friday'] = pomocna_train

pomocna_test = X_38_test['Friday']
pomocna_test = std_scaler.transform(X_38_test['Friday'].values.reshape(-1,1))  
X_38_test['Friday'] = pomocna_test

pomocna_train = X_38_train['Saturday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_38_train['Saturday'].values.reshape(-1,1))  
X_38_train['Saturday'] = pomocna_train

pomocna_test = X_38_test['Saturday']
pomocna_test = std_scaler.transform(X_38_test['Saturday'].values.reshape(-1,1))  
X_38_test['Saturday'] = pomocna_test

pomocna_train = X_38_train['Sunday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_38_train['Sunday'].values.reshape(-1,1))  
X_38_train['Sunday'] = pomocna_train

pomocna_test = X_38_test['Sunday']
pomocna_test = std_scaler.transform(X_38_test['Sunday'].values.reshape(-1,1))  
X_38_test['Sunday'] = pomocna_test

pomocna_train = X_38_train['Weekend']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_38_train['Weekend'].values.reshape(-1,1))  
X_38_train['Weekend'] = pomocna_train

pomocna_test = X_38_test['Weekend']
pomocna_test = std_scaler.transform(X_38_test['Weekend'].values.reshape(-1,1))  
X_38_test['Weekend'] = pomocna_test

# %%
X_38_train.head(5)
# Out:
#             redna_cena  akcijska_cena  n_trgovin    Monday   Tuesday  \
# datum
# 2016-01-02    0.168333       0.168333   0.694068 -0.408596 -0.396352
# 2016-01-03    0.168333       0.168333   0.520846 -0.408596 -0.396352
# 2016-01-04    0.168333       0.168333   0.809550  2.447406 -0.396352
# 2016-01-05    0.168333       0.168333   0.809550 -0.408596  2.523012
# 2016-01-06    0.168333       0.168333   0.982772 -0.408596 -0.396352
#
#             Wednesday  Thursday    Friday  Saturday    Sunday   Weekend
# datum
# 2016-01-02  -0.398814 -0.413449 -0.408596  2.363586 -0.408596  1.546315
# 2016-01-03  -0.398814 -0.413449 -0.408596 -0.423086  2.447406  1.546315
# 2016-01-04  -0.398814 -0.413449 -0.408596 -0.423086 -0.408596 -0.646699
# 2016-01-05  -0.398814 -0.413449 -0.408596 -0.423086 -0.408596 -0.646699
# 2016-01-06   2.507436 -0.413449 -0.408596 -0.423086 -0.408596 -0.646699

# %% [markdown]
# ### Fittamo model na podacima trening seta

# %%
model_38 = lm.fit(X_38_train, y_38_train)

# %%
y_38_train_predicted = model_38.predict(X_38_train)

# %%
model_38.score(X_38_train, y_38_train)
# Out:
# 0.20416174576911528

# %%
mae_38_train = mean_absolute_error(y_38_train, y_38_train_predicted)
mae_38_train
# Out:
# 109.8268136449284

# %%
mse_38_train = mean_squared_error(y_38_train, y_38_train_predicted)
mse_38_train
# Out:
# 19270.787292149857

# %%
rmse_38_train = np.sqrt(mean_squared_error(y_38_train, y_38_train_predicted))
rmse_38_train
# Out:
# 138.81926124335143

# %% [markdown]
# ### TEST

# %%
#X_38_test_scaled = std_scaler.transform(X_38_test)   #kao i u trening setu i ovdje skaliramo stupce zasebno

# %%
y_38_test_predicted = model_38.predict(X_38_test)

# %%
mae_38_test = mean_absolute_error(y_38_test, y_38_test_predicted)
mae_38_test
# Out:
# 129.43120243269968

# %%
mse_38_test = mean_squared_error(y_38_test, y_38_test_predicted)
mse_38_test
# Out:
# 50107.299007588954

# %%
rmse_38_test = np.sqrt(mean_squared_error(y_38_test, y_38_test_predicted))
rmse_38_test
# Out:
# 223.84659704268222

# %%
koeficijenti_38 = model_38.coef_
print(koeficijenti_38)
# Out:
# [ 2.28488889e+15 -2.28488889e+15  2.58339844e+01  9.21181132e+15
#   9.01187737e+15  9.05254334e+15  9.28946876e+15  9.21181132e+15
#  -1.10470824e+15 -1.07789125e+15  1.34004685e+16]

# %%
odsjecak_38 = model_38.intercept_
print(odsjecak_38)
# Out:
# 253.53629552880946

# %%
paramtetri_nagiba_38 = model_38.get_params
print(paramtetri_nagiba_38)
# Out:
# <bound method BaseEstimator.get_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>

# %%
y_38_test_predicted[0:5]
# Out:
# array([146.53629553, 186.53629553, 244.53629553, 329.53629553,
#        177.53629553])

# %%
y_38_test[:10]
# Out:
# datum
# 2018-01-02    307.0
# 2018-01-03    118.0
# 2018-01-04    223.0
# 2018-01-06    429.0
# 2018-01-07     80.0
# 2018-01-08    134.0
# 2018-01-09     67.0
# 2018-01-10    260.0
# 2018-01-11    311.0
# 2018-01-12    273.0
# Name: kol, dtype: float64

# %%
y_38_test_predicted[:10]
# Out:
# array([146.53629553, 186.53629553, 244.53629553, 329.53629553,
#        177.53629553, 186.53629553, 150.53629553, 186.53629553,
#        240.53629553, 224.53629553])

# %%
plt.scatter(y_38_test, y_38_test_predicted)
plt.xlabel("stvarne kolicina")
plt.ylabel("predviđene kolicina")
# Out:
# Text(0, 0.5, 'predviđene kolicina')

# %%
r2_score(y_38_test,y_38_test_predicted)
# Out:
# -0.865687739563628

# %%
rmse_38_test = np.sqrt(mean_squared_error(y_38_test, y_38_test_predicted))
rmse_38_test
# Out:
# 223.84659704268222

# %% [markdown]
# ## Artikl 39

# %%
X_39 = X.loc[39]

# %% [markdown]
# ## Odvajanje podataka u testni i trening set

# %%
X_39_tr = X_39.loc[X_39.index.get_level_values('datum') <= '2018-01-01']
X_39_train = X_39_tr.drop('kol',axis=1)

X_39_te = X_39.loc[X_39.index.get_level_values('datum') > '2018-01-01']
X_39_test = X_39_te.drop('kol',axis=1)

y_39_train = X_39_tr['kol']
y_39_test = X_39_te['kol']

# %%
print (X_39_train.shape, y_39_train.shape)
print (X_39_test.shape, y_39_test.shape)
# Out:
# (724, 11) (724,)
# (145, 11) (145,)

# %% [markdown]
# ### Preprocesiranje **TRAINING** podataka

# %%
#std_scaler.fit(X_39_train)   #skalirat ćemo po svakom stupcu zasebno
#X_39_train_scaled = std_scaler.transform(X_39_train)

# %%
pomocna_train = X_39_train['redna_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_39_train['redna_cena'].values.reshape(-1,1))  
X_39_train['redna_cena'] = pomocna_train

pomocna_test = X_39_test['redna_cena']
pomocna_test = std_scaler.transform(X_39_test['redna_cena'].values.reshape(-1,1))  
X_39_test['redna_cena'] = pomocna_test

pomocna_train = X_39_train['akcijska_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_39_train['akcijska_cena'].values.reshape(-1,1))  
X_39_train['akcijska_cena'] = pomocna_train

pomocna_test = X_39_test['akcijska_cena']
pomocna_test = std_scaler.transform(X_39_test['akcijska_cena'].values.reshape(-1,1))  
X_39_test['akcijska_cena'] = pomocna_test

pomocna_train = X_39_train['n_trgovin']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_39_train['n_trgovin'].values.reshape(-1,1))  
X_39_train['n_trgovin'] = pomocna_train

pomocna_test = X_39_test['n_trgovin']
pomocna_test = std_scaler.transform(X_39_test['n_trgovin'].values.reshape(-1,1))  
X_39_test['n_trgovin'] = pomocna_test

pomocna_train = X_39_train['Monday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_39_train['Monday'].values.reshape(-1,1))  
X_39_train['Monday'] = pomocna_train

pomocna_test = X_39_test['Monday']
pomocna_test = std_scaler.transform(X_39_test['Monday'].values.reshape(-1,1))  
X_39_test['Monday'] = pomocna_test

pomocna_train = X_39_train['Tuesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_39_train['Tuesday'].values.reshape(-1,1))  
X_39_train['Tuesday'] = pomocna_train

pomocna_test = X_39_test['Tuesday']
pomocna_test = std_scaler.transform(X_39_test['Tuesday'].values.reshape(-1,1))  
X_39_test['Tuesday'] = pomocna_test

pomocna_train = X_39_train['Wednesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_39_train['Wednesday'].values.reshape(-1,1))  
X_39_train['Wednesday'] = pomocna_train

pomocna_test = X_39_test['Wednesday']
pomocna_test = std_scaler.transform(X_39_test['Wednesday'].values.reshape(-1,1))  
X_39_test['Wednesday'] = pomocna_test

pomocna_train = X_39_train['Thursday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_39_train['Thursday'].values.reshape(-1,1))  
X_39_train['Thursday'] = pomocna_train

pomocna_test = X_39_test['Thursday']
pomocna_test = std_scaler.transform(X_39_test['Thursday'].values.reshape(-1,1))  
X_39_test['Thursday'] = pomocna_test

pomocna_train = X_39_train['Friday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_39_train['Friday'].values.reshape(-1,1))  
X_39_train['Friday'] = pomocna_train

pomocna_test = X_39_test['Friday']
pomocna_test = std_scaler.transform(X_39_test['Friday'].values.reshape(-1,1))  
X_39_test['Friday'] = pomocna_test

pomocna_train = X_39_train['Saturday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_39_train['Saturday'].values.reshape(-1,1))  
X_39_train['Saturday'] = pomocna_train

pomocna_test = X_39_test['Saturday']
pomocna_test = std_scaler.transform(X_39_test['Saturday'].values.reshape(-1,1))  
X_39_test['Saturday'] = pomocna_test

pomocna_train = X_39_train['Sunday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_39_train['Sunday'].values.reshape(-1,1))  
X_39_train['Sunday'] = pomocna_train

pomocna_test = X_39_test['Sunday']
pomocna_test = std_scaler.transform(X_39_test['Sunday'].values.reshape(-1,1))  
X_39_test['Sunday'] = pomocna_test

pomocna_train = X_39_train['Weekend']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_39_train['Weekend'].values.reshape(-1,1))  
X_39_train['Weekend'] = pomocna_train

pomocna_test = X_39_test['Weekend']
pomocna_test = std_scaler.transform(X_39_test['Weekend'].values.reshape(-1,1))  
X_39_test['Weekend'] = pomocna_test

# %% [markdown]
# ### Fittamo model na podacima trening seta

# %%
model_39 = lm.fit(X_39_train, y_39_train)

# %%
y_39_train_predicted = model_39.predict(X_39_train)

# %%
model_39.score(X_39_train, y_39_train)
# Out:
# 0.28418584123908486

# %%
mae_39_train = mean_absolute_error(y_39_train, y_39_train_predicted)
mae_39_train
# Out:
# 1206.4096050946282

# %%
mse_39_train = mean_squared_error(y_39_train, y_39_train_predicted)
mse_39_train
# Out:
# 2454488.157638209

# %%
rmse_39_train = np.sqrt(mean_squared_error(y_39_train, y_39_train_predicted))
rmse_39_train
# Out:
# 1566.6806176238374

# %% [markdown]
# ### TEST

# %%
#X_39_test_scaled = std_scaler.transform(X_39_test)   #kao i u trening setu i ovdje skaliramo stupce zasebno

# %%
y_39_test_predicted = model_39.predict(X_39_test)

# %%
mae_39_test = mean_absolute_error(y_39_test, y_39_test_predicted)
mae_39_test
# Out:
# 1004.1112762694793

# %%
mse_39_test = mean_squared_error(y_39_test, y_39_test_predicted)
mse_39_test
# Out:
# 1683437.3442641904

# %%
koeficijenti_39 = model_39.coef_
print(koeficijenti_39)
# Out:
# [ 1.38310917e+16 -1.38310917e+16 -5.48437500e+01  1.08759493e+17
#   1.09198149e+17  1.08759493e+17  1.09198149e+17  1.09198149e+17
#  -3.25244189e+14 -3.20017909e+14  1.40892458e+17]

# %%
odsjecak_39 = model_39.intercept_
print(odsjecak_39)
# Out:
# 3435.0034630531923

# %%
paramtetri_nagiba_39 = model_39.get_params
print(paramtetri_nagiba_39)
# Out:
# <bound method BaseEstimator.get_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>

# %%
y_39_test_predicted[0:5]
# Out:
# array([2459.00346305, 2747.00346305, 4411.00346305, 4443.00346305,
#        5259.00346305])

# %%
y_39_test[:10]
# Out:
# datum
# 2018-01-02    2033.0
# 2018-01-03    2777.0
# 2018-01-04    3817.0
# 2018-01-05    2417.0
# 2018-01-06    3414.0
# 2018-01-07    1653.0
# 2018-01-08    1729.0
# 2018-01-09    1254.0
# 2018-01-10    5149.0
# 2018-01-11    4036.0
# Name: kol, dtype: float64

# %%
y_39_test_predicted[:10]
# Out:
# array([2459.00346305, 2747.00346305, 4411.00346305, 4443.00346305,
#        5259.00346305, 2763.00346305, 2779.00346305, 2459.00346305,
#        2779.00346305, 4395.00346305])

# %%
plt.scatter(y_39_test, y_39_test_predicted)
plt.xlabel("stvarne kolicina")
plt.ylabel("predviđene kolicina")
# Out:
# Text(0, 0.5, 'predviđene kolicina')

# %%
r2_score(y_39_test,y_39_test_predicted)
# Out:
# 0.33908357894200547

# %%
rmse_39_test = np.sqrt(mean_squared_error(y_39_test, y_39_test_predicted))
rmse_39_test
# Out:
# 1297.4734464582273

# %% [markdown]
# ## Artikl 40

# %%
X_40 = X.loc[40]

# %% [markdown]
# ## Odvajanje podataka u testni i trening set

# %%
X_40_tr = X_40.loc[X_40.index.get_level_values('datum') <= '2018-01-01']
X_40_train = X_40_tr.drop('kol',axis=1)

X_40_te = X_40.loc[X_40.index.get_level_values('datum') > '2018-01-01']
X_40_test = X_40_te.drop('kol',axis=1)

y_40_train = X_40_tr['kol']
y_40_test = X_40_te['kol']

# %%
print (X_40_train.shape, y_40_train.shape)
print (X_40_test.shape, y_40_test.shape)
# Out:
# (724, 11) (724,)
# (145, 11) (145,)

# %% [markdown]
# ### Preprocesiranje **TRAINING** podataka

# %%
#std_scaler.fit(X_40_train)   #skalirat ćemo po svakom stupcu zasebno
#X_40_train_scaled = std_scaler.transform(X_40_train)

# %%
pomocna_train = X_40_train['redna_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_40_train['redna_cena'].values.reshape(-1,1))  
X_40_train['redna_cena'] = pomocna_train

pomocna_test = X_40_test['redna_cena']
pomocna_test = std_scaler.transform(X_40_test['redna_cena'].values.reshape(-1,1))  
X_40_test['redna_cena'] = pomocna_test

pomocna_train = X_40_train['akcijska_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_40_train['akcijska_cena'].values.reshape(-1,1))  
X_40_train['akcijska_cena'] = pomocna_train

pomocna_test = X_40_test['akcijska_cena']
pomocna_test = std_scaler.transform(X_40_test['akcijska_cena'].values.reshape(-1,1))  
X_40_test['akcijska_cena'] = pomocna_test

pomocna_train = X_40_train['n_trgovin']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_40_train['n_trgovin'].values.reshape(-1,1))  
X_40_train['n_trgovin'] = pomocna_train

pomocna_test = X_40_test['n_trgovin']
pomocna_test = std_scaler.transform(X_40_test['n_trgovin'].values.reshape(-1,1))  
X_40_test['n_trgovin'] = pomocna_test

pomocna_train = X_40_train['Monday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_40_train['Monday'].values.reshape(-1,1))  
X_40_train['Monday'] = pomocna_train

pomocna_test = X_40_test['Monday']
pomocna_test = std_scaler.transform(X_40_test['Monday'].values.reshape(-1,1))  
X_40_test['Monday'] = pomocna_test

pomocna_train = X_40_train['Tuesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_40_train['Tuesday'].values.reshape(-1,1))  
X_40_train['Tuesday'] = pomocna_train

pomocna_test = X_40_test['Tuesday']
pomocna_test = std_scaler.transform(X_40_test['Tuesday'].values.reshape(-1,1))  
X_40_test['Tuesday'] = pomocna_test

pomocna_train = X_40_train['Wednesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_40_train['Wednesday'].values.reshape(-1,1))  
X_40_train['Wednesday'] = pomocna_train

pomocna_test = X_40_test['Wednesday']
pomocna_test = std_scaler.transform(X_40_test['Wednesday'].values.reshape(-1,1))  
X_40_test['Wednesday'] = pomocna_test

pomocna_train = X_40_train['Thursday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_40_train['Thursday'].values.reshape(-1,1))  
X_40_train['Thursday'] = pomocna_train

pomocna_test = X_40_test['Thursday']
pomocna_test = std_scaler.transform(X_40_test['Thursday'].values.reshape(-1,1))  
X_40_test['Thursday'] = pomocna_test

pomocna_train = X_40_train['Friday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_40_train['Friday'].values.reshape(-1,1))  
X_40_train['Friday'] = pomocna_train

pomocna_test = X_40_test['Friday']
pomocna_test = std_scaler.transform(X_40_test['Friday'].values.reshape(-1,1))  
X_40_test['Friday'] = pomocna_test

pomocna_train = X_40_train['Saturday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_40_train['Saturday'].values.reshape(-1,1))  
X_40_train['Saturday'] = pomocna_train

pomocna_test = X_40_test['Saturday']
pomocna_test = std_scaler.transform(X_40_test['Saturday'].values.reshape(-1,1))  
X_40_test['Saturday'] = pomocna_test

pomocna_train = X_40_train['Sunday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_40_train['Sunday'].values.reshape(-1,1))  
X_40_train['Sunday'] = pomocna_train

pomocna_test = X_40_test['Sunday']
pomocna_test = std_scaler.transform(X_40_test['Sunday'].values.reshape(-1,1))  
X_40_test['Sunday'] = pomocna_test

pomocna_train = X_40_train['Weekend']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_40_train['Weekend'].values.reshape(-1,1))  
X_40_train['Weekend'] = pomocna_train

pomocna_test = X_40_test['Weekend']
pomocna_test = std_scaler.transform(X_40_test['Weekend'].values.reshape(-1,1))  
X_40_test['Weekend'] = pomocna_test

# %% [markdown]
# ### Fittamo model na podacima trening seta

# %%
model_40 = lm.fit(X_40_train, y_40_train)

# %%
y_40_train_predicted = model_40.predict(X_40_train)

# %%
model_40.score(X_40_train, y_40_train)
# Out:
# 0.4476470757622077

# %%
mae_40_train = mean_absolute_error(y_40_train, y_40_train_predicted)
mae_40_train
# Out:
# 60.693346698583916

# %%
mse_40_train = mean_squared_error(y_40_train, y_40_train_predicted)
mse_40_train
# Out:
# 8145.793090136846

# %%
rmse_40_train = np.sqrt(mean_squared_error(y_40_train, y_40_train_predicted))
rmse_40_train
# Out:
# 90.25404750002542

# %% [markdown]
# ### TEST

# %%
#X_40_test_scaled = std_scaler.transform(X_40_test)   #kao i u trening setu i ovdje skaliramo stupce zasebno

# %%
y_40_test_predicted = model_40.predict(X_40_test)

# %%
mae_40_test = mean_absolute_error(y_40_test, y_40_test_predicted)
mae_40_test
# Out:
# 47.85742932267559

# %%
mse_40_test = mean_squared_error(y_40_test, y_40_test_predicted)
mse_40_test
# Out:
# 3701.3160939536747

# %%
rmse_40_test = np.sqrt(mean_squared_error(y_40_test, y_40_test_predicted))
rmse_40_test
# Out:
# 60.83844256679879

# %%
koeficijenti_40 = model_40.coef_
print(koeficijenti_40)
# Out:
# [-23.11559411 -47.66402501  18.5872227  -10.63428146 -10.29994307
#   -5.35952603  18.76932161  18.84199937  15.42190553 -27.19554087
#   -8.84760412]

# %%
odsjecak_40 = model_40.intercept_
print(odsjecak_40)
# Out:
# 165.02624248205566

# %%
paramtetri_nagiba_40 = model_40.get_params
print(paramtetri_nagiba_40)
# Out:
# <bound method BaseEstimator.get_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>

# %%
y_40_test_predicted[0:5]
# Out:
# array([ 92.2938795 , 105.34275577, 174.20030027, 174.35410609,
#        145.48692609])

# %%
y_40_test[:10]
# Out:
# datum
# 2018-01-02     30.0
# 2018-01-03     76.0
# 2018-01-04    103.0
# 2018-01-05    138.0
# 2018-01-06    120.0
# 2018-01-07     41.0
# 2018-01-08     87.0
# 2018-01-09     54.0
# 2018-01-10     86.0
# 2018-01-11     85.0
# Name: kol, dtype: float64

# %%
y_40_test_predicted[:10]
# Out:
# array([ 92.2938795 , 105.34275577, 174.20030027, 174.35410609,
#        145.48692609,  23.1975923 ,  91.16491201,  93.52339959,
#        106.87965588, 175.73720038])

# %%
plt.scatter(y_40_test, y_40_test_predicted)
plt.xlabel("stvarne kolicina")
plt.ylabel("predviđene kolicina")
# Out:
# Text(0, 0.5, 'predviđene kolicina')

# %%
r2_score(y_40_test,y_40_test_predicted)
# Out:
# 0.21949517761635018

# %%
rmse_40_test = np.sqrt(mean_squared_error(y_40_test, y_40_test_predicted))
rmse_40_test
# Out:
# 60.83844256679879

# %% [markdown]
# ## Artikl 41

# %%
X_41 = X.loc[41]

# %% [markdown]
# ## Odvajanje podataka u testni i trening set

# %%
X_41_tr = X_41.loc[X_41.index.get_level_values('datum') <= '2018-01-01']
X_41_train = X_41_tr.drop('kol',axis=1)

X_41_te = X_41.loc[X_41.index.get_level_values('datum') > '2018-01-01']
X_41_test = X_41_te.drop('kol',axis=1)

y_41_train = X_41_tr['kol']
y_41_test = X_41_te['kol']

# %%
print (X_41_train.shape, y_41_train.shape)
print (X_41_test.shape, y_41_test.shape)
# Out:
# (722, 11) (722,)
# (145, 11) (145,)

# %% [markdown]
# ### Preprocesiranje **TRAINING** podataka

# %%
#std_scaler.fit(X_41_train)   #skalirat ćemo po svakom stupcu zasebno
#X_41_train_scaled = std_scaler.transform(X_41_train)

# %%
pomocna_train = X_41_train['redna_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_41_train['redna_cena'].values.reshape(-1,1))  
X_41_train['redna_cena'] = pomocna_train

pomocna_test = X_41_test['redna_cena']
pomocna_test = std_scaler.transform(X_41_test['redna_cena'].values.reshape(-1,1))  
X_41_test['redna_cena'] = pomocna_test

pomocna_train = X_41_train['akcijska_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_41_train['akcijska_cena'].values.reshape(-1,1))  
X_41_train['akcijska_cena'] = pomocna_train

pomocna_test = X_41_test['akcijska_cena']
pomocna_test = std_scaler.transform(X_41_test['akcijska_cena'].values.reshape(-1,1))  
X_41_test['akcijska_cena'] = pomocna_test

pomocna_train = X_41_train['n_trgovin']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_41_train['n_trgovin'].values.reshape(-1,1))  
X_41_train['n_trgovin'] = pomocna_train

pomocna_test = X_41_test['n_trgovin']
pomocna_test = std_scaler.transform(X_41_test['n_trgovin'].values.reshape(-1,1))  
X_41_test['n_trgovin'] = pomocna_test

pomocna_train = X_41_train['Monday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_41_train['Monday'].values.reshape(-1,1))  
X_41_train['Monday'] = pomocna_train

pomocna_test = X_41_test['Monday']
pomocna_test = std_scaler.transform(X_41_test['Monday'].values.reshape(-1,1))  
X_41_test['Monday'] = pomocna_test

pomocna_train = X_41_train['Tuesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_41_train['Tuesday'].values.reshape(-1,1))  
X_41_train['Tuesday'] = pomocna_train

pomocna_test = X_41_test['Tuesday']
pomocna_test = std_scaler.transform(X_41_test['Tuesday'].values.reshape(-1,1))  
X_41_test['Tuesday'] = pomocna_test

pomocna_train = X_41_train['Wednesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_41_train['Wednesday'].values.reshape(-1,1))  
X_41_train['Wednesday'] = pomocna_train

pomocna_test = X_41_test['Wednesday']
pomocna_test = std_scaler.transform(X_41_test['Wednesday'].values.reshape(-1,1))  
X_41_test['Wednesday'] = pomocna_test

pomocna_train = X_41_train['Thursday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_41_train['Thursday'].values.reshape(-1,1))  
X_41_train['Thursday'] = pomocna_train

pomocna_test = X_41_test['Thursday']
pomocna_test = std_scaler.transform(X_41_test['Thursday'].values.reshape(-1,1))  
X_41_test['Thursday'] = pomocna_test

pomocna_train = X_41_train['Friday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_41_train['Friday'].values.reshape(-1,1))  
X_41_train['Friday'] = pomocna_train

pomocna_test = X_41_test['Friday']
pomocna_test = std_scaler.transform(X_41_test['Friday'].values.reshape(-1,1))  
X_41_test['Friday'] = pomocna_test

pomocna_train = X_41_train['Saturday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_41_train['Saturday'].values.reshape(-1,1))  
X_41_train['Saturday'] = pomocna_train

pomocna_test = X_41_test['Saturday']
pomocna_test = std_scaler.transform(X_41_test['Saturday'].values.reshape(-1,1))  
X_41_test['Saturday'] = pomocna_test

pomocna_train = X_41_train['Sunday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_41_train['Sunday'].values.reshape(-1,1))  
X_41_train['Sunday'] = pomocna_train

pomocna_test = X_41_test['Sunday']
pomocna_test = std_scaler.transform(X_41_test['Sunday'].values.reshape(-1,1))  
X_41_test['Sunday'] = pomocna_test

pomocna_train = X_41_train['Weekend']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_41_train['Weekend'].values.reshape(-1,1))  
X_41_train['Weekend'] = pomocna_train

pomocna_test = X_41_test['Weekend']
pomocna_test = std_scaler.transform(X_41_test['Weekend'].values.reshape(-1,1))  
X_41_test['Weekend'] = pomocna_test

# %% [markdown]
# ### Fittamo model na podacima trening seta

# %%
model_41 = lm.fit(X_41_train, y_41_train)

# %%
y_41_train_predicted = model_41.predict(X_41_train)

# %%
model_41.score(X_41_train, y_41_train)
# Out:
# 0.5434455379265195

# %%
mae_41_train = mean_absolute_error(y_41_train, y_41_train_predicted)
mae_41_train
# Out:
# 7.993140668529025

# %%
mse_41_train = mean_squared_error(y_41_train, y_41_train_predicted)
mse_41_train
# Out:
# 115.88408652112331

# %%
rmse_41_train = np.sqrt(mean_squared_error(y_41_train, y_41_train_predicted))
rmse_41_train
# Out:
# 10.764947121148497

# %% [markdown]
# ### TEST

# %%
#X_41_test = std_scaler.transform(X_41_test)   #kao i u trening setu i ovdje skaliramo stupce zasebno

# %%
y_41_test_predicted = model_41.predict(X_41_test)

# %%
mae_41_test = mean_absolute_error(y_41_test, y_41_test_predicted)
mae_41_test
# Out:
# 9.57912704436671

# %%
mse_41_test = mean_squared_error(y_41_test, y_41_test_predicted)
mse_41_test
# Out:
# 138.61248560896783

# %%
rmse_41_test = np.sqrt(mean_squared_error(y_41_test, y_41_test_predicted))
rmse_41_test
# Out:
# 11.7733803815628

# %%
koeficijenti_41 = model_41.coef_
print(koeficijenti_41)
# Out:
# [-3.98171263e+00  1.38483738e-01  1.08162386e+00 -2.82223013e+14
#  -2.82223013e+14 -2.82223013e+14 -2.83360555e+14 -2.83360555e+14
#  -9.49965250e+14 -9.30819944e+14  8.51172197e+14]

# %%
odsjecak_41 = model_41.intercept_
print(odsjecak_41)
# Out:
# 30.87605829498035

# %%
paramtetri_nagiba_41 = model_41.get_params
print(paramtetri_nagiba_41)
# Out:
# <bound method BaseEstimator.get_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>

# %%
y_41_test_predicted[0:5]
# Out:
# array([19.56355829, 35.06355829, 42.68855829, 37.18855829, 28.12605829])

# %%
y_41_test[:10]
# Out:
# datum
# 2018-01-02     9.0
# 2018-01-03    30.0
# 2018-01-04    31.0
# 2018-01-05    22.0
# 2018-01-06    26.0
# 2018-01-07     6.0
# 2018-01-08    21.0
# 2018-01-09    15.0
# 2018-01-10    15.0
# 2018-01-11    37.0
# Name: kol, dtype: float64

# %%
y_41_test_predicted[:10]
# Out:
# array([19.56355829, 35.06355829, 42.68855829, 37.18855829, 28.12605829,
#         7.37605829, 27.93855829, 19.56355829, 21.56355829, 49.43855829])

# %%
plt.scatter(y_41_test, y_41_test_predicted)
plt.xlabel("stvarne kolicina")
plt.ylabel("predviđene kolicina")
# Out:
# Text(0, 0.5, 'predviđene kolicina')

# %%
r2_score(y_41_test,y_41_test_predicted)
# Out:
# 0.27257218674359407

# %%
rmse_41_test = np.sqrt(mean_squared_error(y_41_test, y_41_test_predicted))
rmse_41_test
# Out:
# 11.7733803815628

# %% [markdown]
# ## Artikl 57

# %%
X_57 = X.loc[57]
X_57
# Out:
#             redna_cena  akcijska_cena  n_trgovin    kol  Monday  Tuesday  \
# datum
# 2016-01-02       0.081          0.081        103   73.0       0        0
# 2016-01-03       0.082          0.082        101    4.0       0        0
# 2016-01-04       0.080          0.080        102   34.0       1        0
# 2016-01-05       0.082          0.082        101   27.0       0        1
# 2016-01-06       0.080          0.080        101   61.0       0        0
# 2016-01-07       0.081          0.081        102   60.0       0        0
# 2016-01-08       0.080          0.080        103   17.0       0        0
# 2016-01-09       0.081          0.081        101   56.0       0        0
# 2016-01-10       0.080          0.080        100   45.0       0        0
# 2016-01-11       0.081          0.081        104   82.0       1        0
# 2016-01-12       0.085          0.085        103    4.0       0        1
# 2016-01-13       0.082          0.082        103   20.0       0        0
# 2016-01-14       0.081          0.081        104   69.0       0        0
# 2016-01-15       0.081          0.081        103   47.0       0        0
# 2016-01-16       0.080          0.080        101   61.0       0        0
# 2016-01-17       0.082          0.082        102   14.0       0        0
# 2016-01-18       0.081          0.081        103   33.0       1        0
# 2016-01-19       0.081          0.081        104   67.0       0        1
# ...              ...     ...       ...     ...      ...
# 2018-04-26         1       0         0       0        0
# 2018-04-27         0       1         0       0        0
# 2018-04-28         0       0         1       0        1
# 2018-04-29         0       0         0       1        1
# 2018-05-02         0       0         0       0        0
# 2018-05-03         1       0         0       0        0
# 2018-05-04         0       1         0       0        0
# 2018-05-05         0       0         1       0        1
# 2018-05-06         0       0         0       1        1
# 2018-05-07         0       0         0       0        0
# 2018-05-08         0       0         0       0        0
# 2018-05-09         0       0         0       0        0
# 2018-05-10         1       0         0       0        0
# 2018-05-11         0       1         0       0        0
# 2018-05-13         0       0         0       1        1
# 2018-05-14         0       0         0       0        0
# 2018-05-15         0       0         0       0        0
# 2018-05-17         1       0         0       0        0
# 2018-05-18         0       1         0       0        0
# 2018-05-19         0       0         1       0        1
# 2018-05-21         0       0         0       0        0
# 2018-05-22         0       0         0       0        0
# 2018-05-23         0       0         0       0        0
# 2018-05-24         1       0         0       0        0
# 2018-05-25         0       1         0       0        0
# 2018-05-26         0       0         1       0        1
# 2018-05-27         0       0         0       1        1
# 2018-05-28         0       0         0       0        0
# 2018-05-30         0       0         0       0        0
# 2018-05-31         1       0         0       0        0
#
# [121 rows x 11 columns]

# %%
print (X_57_train.shape, y_57_train.shape)
print (X_57_test.shape, y_57_test.shape)
# Out:
# (680, 11) (680,)
# (121, 11) (121,)

# %% [markdown]
# ### Preprocesiranje **TRAINING** podataka

# %%
pomocna_train = X_57_train['redna_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['redna_cena'].values.reshape(-1,1))  
X_57_train['redna_cena'] = pomocna_train

pomocna_test = X_57_test['redna_cena']
pomocna_test = std_scaler.transform(X_57_test['redna_cena'].values.reshape(-1,1))  
X_57_test['redna_cena'] = pomocna_test

# %%
pomocna_train = X_57_train['akcijska_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['akcijska_cena'].values.reshape(-1,1))  
X_57_train['akcijska_cena'] = pomocna_train

pomocna_test = X_57_test['akcijska_cena']
pomocna_test = std_scaler.transform(X_57_test['akcijska_cena'].values.reshape(-1,1))  
X_57_test['akcijska_cena'] = pomocna_test

# %%
pomocna_train = X_57_train['n_trgovin']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['n_trgovin'].values.reshape(-1,1))  
X_57_train['n_trgovin'] = pomocna_train

pomocna_test = X_57_test['n_trgovin']
pomocna_test = std_scaler.transform(X_57_test['n_trgovin'].values.reshape(-1,1))  
X_57_test['n_trgovin'] = pomocna_test

# %%
pomocna_train = X_57_train['Monday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Monday'].values.reshape(-1,1))  
X_57_train['Monday'] = pomocna_train

pomocna_test = X_57_test['Monday']
pomocna_test = std_scaler.transform(X_57_test['Monday'].values.reshape(-1,1))  
X_57_test['Monday'] = pomocna_test

# %%
pomocna_train = X_57_train['Tuesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Tuesday'].values.reshape(-1,1))  
X_57_train['Tuesday'] = pomocna_train

pomocna_test = X_57_test['Tuesday']
pomocna_test = std_scaler.transform(X_57_test['Tuesday'].values.reshape(-1,1))  
X_57_test['Tuesday'] = pomocna_test

# %%
pomocna_train = X_57_train['Wednesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Wednesday'].values.reshape(-1,1))  
X_57_train['Wednesday'] = pomocna_train

pomocna_test = X_57_test['Wednesday']
pomocna_test = std_scaler.transform(X_57_test['Wednesday'].values.reshape(-1,1))  
X_57_test['Wednesday'] = pomocna_test

# %%
pomocna_train = X_57_train['Thursday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Thursday'].values.reshape(-1,1))  
X_57_train['Thursday'] = pomocna_train

pomocna_test = X_57_test['Thursday']
pomocna_test = std_scaler.transform(X_57_test['Thursday'].values.reshape(-1,1))  
X_57_test['Thursday'] = pomocna_test

# %%
pomocna_train = X_57_train['Friday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Friday'].values.reshape(-1,1))  
X_57_train['Friday'] = pomocna_train

pomocna_test = X_57_test['Friday']
pomocna_test = std_scaler.transform(X_57_test['Friday'].values.reshape(-1,1))  
X_57_test['Friday'] = pomocna_test

# %%
pomocna_train = X_57_train['Saturday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Saturday'].values.reshape(-1,1))  
X_57_train['Saturday'] = pomocna_train

pomocna_test = X_57_test['Saturday']
pomocna_test = std_scaler.transform(X_57_test['Saturday'].values.reshape(-1,1))  
X_57_test['Saturday'] = pomocna_test

# %%
pomocna_train = X_57_train['Sunday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Sunday'].values.reshape(-1,1))  
X_57_train['Sunday'] = pomocna_train

pomocna_test = X_57_test['Sunday']
pomocna_test = std_scaler.transform(X_57_test['Sunday'].values.reshape(-1,1))  
X_57_test['Sunday'] = pomocna_test

# %%
pomocna_train = X_57_train['Weekend']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Weekend'].values.reshape(-1,1))  
X_57_train['Weekend'] = pomocna_train

pomocna_test = X_57_test['Weekend']
pomocna_test = std_scaler.transform(X_57_test['Weekend'].values.reshape(-1,1))  
X_57_test['Weekend'] = pomocna_test

# %%
X_57_train
# Out:
#             redna_cena  akcijska_cena  n_trgovin    Monday   Tuesday  \
# datum
# 2016-01-02    0.113910       0.113910   1.600239 -0.407898 -0.395554
# 2016-01-03    0.572246       0.572246   1.357427 -0.407898 -0.395554
# 2016-01-04   -0.344426      -0.344426   1.478833  2.451593 -0.395554
# 2016-01-05    0.572246       0.572246   1.357427 -0.407898  2.528103
# 2016-01-06   -0.344426      -0.344426   1.357427 -0.407898 -0.395554
# 2016-01-07    0.113910       0.113910   1.478833 -0.407898 -0.395554
# 2016-01-08   -0.344426      -0.344426   1.600239 -0.407898 -0.395554
# 2016-01-09    0.113910       0.113910   1.357427 -0.407898 -0.395554
# 2016-01-10   -0.344426      -0.344426   1.236021 -0.407898 -0.395554
# 2016-01-11    0.113910       0.113910   1.721645  2.451593 -0.395554
# 2016-01-12    1.947251       1.947251   1.600239 -0.407898  2.528103
# 2016-01-13    0.572246       0.572246   1.600239 -0.407898 -0.395554
# 2016-01-14    0.113910       0.113910   1.721645 -0.407898 -0.395554
# 2016-01-15    0.113910       0.113910   1.600239 -0.407898 -0.395554
# 2016-01-16   -0.344426      -0.344426   1.357427 -0.407898 -0.395554
# 2016-01-17    0.572246       0.572246   1.478833 -0.407898 -0.395554
# 2016-01-18    0.113910       0.113910   1.600239  2.451593 -0.395554
# 2016-01-19    0.113910       0.113910   1.721645 -0.407898  2.528103
# 2016-01-20   -0.344426      -0.344426   1.478833 -0.407898 -0.395554
# 2016-01-21   -0.344426      -0.344426   1.600239 -0.407898 -0.395554
# 2016-01-22   -0.344426      -0.344426   1.721645 -0.407898 -0.395554
# 2016-01-23    0.113910       0.113910   1.600239 -0.407898 -0.395554
-0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
#
# [680 rows x 11 columns]

# %%
#std_scaler.fit(X_57_train)   #skalirat ćemo po svakom stupcu zasebno
#X_57_train_scaled = std_scaler.transform(X_57_train)  

# colT = ColumnTransformer([("dummy_col", OneHotEncoder(),[0,1,2,3,4,10]), ("norm", Normalizer(norm='l1'), [5,6,7,8,9])])
# colT = ColumnTransformer([('StdSkaler_redna_cena', StandardScaler(), 'redna_cena')], remainder='passthrough')

# X_train = colT.fit_transform(X_train)

#X_train['redna_cena'] = X_train['redna_cena'].apply(lambda x: StandardScaler().fit_transform(x))
# X_57_train_scaled

# %%
X_57_test
# Out:
#             redna_cena  akcijska_cena  n_trgovin    Monday   Tuesday  \
# datum
# 2018-01-02   -0.344426      -0.344426  -1.313506 -0.407898  2.528103
# 2018-01-03   -0.344426      -0.344426  -1.313506 -0.407898 -0.395554
# 2018-01-04    0.113910       0.113910  -1.070694 -0.407898 -0.395554
# 2018-01-05   -0.344426      -0.344426  -1.192100 -0.407898 -0.395554
# 2018-01-06    0.113910       0.113910  -1.070694 -0.407898 -0.395554
# 2018-01-07   -0.344426      -0.344426  -1.070694 -0.407898 -0.395554
# 2018-01-08   -0.344426      -0.344426  -1.070694  2.451593 -0.395554
# 2018-01-10    0.113910       0.113910  -1.192100 -0.407898 -0.395554
# 2018-01-11   -0.344426      -0.344426  -1.192100 -0.407898 -0.395554
# 2018-01-12   -0.344426      -0.344426  -1.070694 -0.407898 -0.395554
# 2018-01-14   -0.344426      -0.344426  -1.070694 -0.407898 -0.395554
# 2018-01-15    0.572246       0.572246  -1.070694  2.451593 -0.395554
# 2018-01-16    0.113910       0.113910  -1.070694 -0.407898  2.528103
# 2018-01-17    1.030579       1.030579  -1.070694 -0.407898 -0.395554
# 2018-01-18   -0.344426      -0.344426  -1.313506 -0.407898 -0.395554
# 2018-01-19   -0.344426      -0.344426  -1.313506 -0.407898 -0.395554
# 2018-01-20    0.113910       0.113910  -1.313506 -0.407898 -0.395554
# 2018-01-22   -0.344426      -0.344426  -1.313506  2.451593 -0.395554
# 2018-01-23    0.572246       0.572246  -1.192100 -0.407898  2.528103
# 2018-01-24    0.113910       0.113910  -1.313506 -0.407898 -0.395554
# 2018-01-25   -0.344426      -0.344426  -1.192100 -0.407898 -0.395554
# 2018-01-26    0.113910       0.113910  -1.192100 -0.407898 -0.395554
# 2018-01-27    0.113910       0.113910  -1.313506 -0.407898 -0.395554
# 2018-01-28    0.113910       0.113910  -1.192100 -0.407898 -0.395554
# 2018-01-29    0.113910       0.113910  -1.192100  2.451593 -0.395554
# 2018-01-30    0.572246       0.572246  -1.192100 -0.407898  2.528103
# 2018-01-31    0.113910       0.113910  -1.192100 -0.407898 -0.395554
# 2018-02-01    0.113910       0.113910  -1.070694 -0.407898 -0.395554
# 2018-02-02   -0.344426      -0.344426  -1.070694 -0.407898 -0.395554
# 2018-02-04    1.947251       1.947251  -1.192100 -0.407898 -0.395554
# ...                ...            ...        ...       ...       ...
# 2018-04-26   -0.344426      -0.344426  -1.677725 -0.407898 -0.395554
# 2018-04-27   -0.344426      -0.344426  -1.677725 -0.407898 -0.395554
# 2018-04-28    0.113910       0.113910  -1.677725 -0.407898 -0.395554
# 2018-04-29   -0.344426      -0.344426  -1.920537 -0.407898 -0.395554
# 2018-05-02   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-03   -0.344426      -0.344426  -1.677725 -0.407898 -0.395554
# 2018-05-04   -0.344426      -0.344426  -1.556319 -0.407898 -0.395554
# 2018-05-05   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-06   -0.344426      -0.344426  -1.677725 -0.407898 -0.395554
# 2018-05-07    0.113910       0.113910  -1.434913  2.451593 -0.395554
# 2018-05-08   -0.344426      -0.344426  -1.677725 -0.407898  2.528103
# 2018-05-09   -0.344426      -0.344426  -1.920537 -0.407898 -0.395554
# 2018-05-10   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-11   -0.344426      -0.344426  -1.677725 -0.407898 -0.395554
# 2018-05-13    0.113910       0.113910  -2.163349 -0.407898 -0.395554
# 2018-05-14    0.113910       0.113910  -2.163349  2.451593 -0.395554
# 2018-05-15   -0.344426      -0.344426  -2.041943 -0.407898  2.528103
# 2018-05-17   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-18   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-19    0.113910       0.113910  -1.920537 -0.407898 -0.395554
# 2018-05-21   -0.344426      -0.344426  -1.799131  2.451593 -0.395554
# 2018-05-22    0.572246       0.572246  -1.920537 -0.407898  2.528103
# 2018-05-23   -0.344426      -0.344426  -1.920537 -0.407898 -0.395554
# 2018-05-24   -0.344426      -0.344426  -2.041943 -0.407898 -0.395554
# 2018-05-25    0.113910       0.113910  -1.920537 -0.407898 -0.395554
# 2018-05-26   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-27   -0.344426      -0.344426  -2.163349 -0.407898 -0.395554
# 2018-05-28    0.113910       0.113910  -1.920537  2.451593 -0.395554
# 2018-05-30   -0.344426      -0.344426  -2.284755 -0.407898 -0.395554
# 2018-05-31   -0.344426      -0.344426  -2.041943 -0.407898 -0.395554
#
#             Wednesday  Thursday    Friday  Saturday    Sunday   Weekend
# datum
# 2018-01-02  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-03   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-04  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-05  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-01-06  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-01-07  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-01-08  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-10   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-11  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-12  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-01-14  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-01-15  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-16  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-17   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-18  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-19  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-01-20  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-01-22  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-23  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-24   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-25  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-26  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-01-27  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-01-28  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-01-29  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-30  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-31   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-02-01  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-02-02  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-02-04  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# ...               ...       ...       ...       ...       ...       ...
# 2018-04-26  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-04-27  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-04-28  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-04-29  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-05-02   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-03  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-04  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-05-05  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-05-06  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-05-07  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-08  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-09   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-10  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-11  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-05-13  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-05-14  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-15  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-17  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-18  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-05-19  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-05-21  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-22  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-23   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-24  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-25  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-05-26  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-05-27  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-05-28  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-30   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-31  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
#
# [121 rows x 11 columns]

# %% [markdown]
# ### Fittamo model na podacima trening seta

# %%
model_57 = lm.fit(X_57_train, y_57_train)

# %%
y_57_train_predicted = model_57.predict(X_57_train)

# %%
model_57.score(X_57_train, y_57_train)
# Out:
# 0.208269177598863

# %%
mae_57_train = mean_absolute_error(y_57_train, y_57_train_predicted)
mae_57_train
# Out:
# 23.985476649649012

# %%
mse_57_train = mean_squared_error(y_57_train, y_57_train_predicted)
mse_57_train
# Out:
# 1128.8553884188168

# %%
rmse_57_train = np.sqrt(mean_squared_error(y_57_train, y_57_train_predicted))
rmse_57_train
# Out:
# 33.59844324397809

# %% [markdown]
# ### TEST

# %%
# X_57_test_scaled = std_scaler.transform(X_57_test)   #kao i u trening setu i ovdje skaliramo stupce zasebno

# %%
X_57_test
# Out:
#             redna_cena  akcijska_cena  n_trgovin    Monday   Tuesday  \
# datum
# 2018-01-02   -0.344426      -0.344426  -1.313506 -0.407898  2.528103
# 2018-01-03   -0.344426      -0.344426  -1.313506 -0.407898 -0.395554
# 2018-01-04    0.113910       0.113910  -1.070694 -0.407898 -0.395554
# 2018-01-05   -0.344426      -0.344426  -1.192100 -0.407898 -0.395554
# 2018-01-06    0.113910       0.113910  -1.070694 -0.407898 -0.395554
# 2018-01-07   -0.344426      -0.344426  -1.070694 -0.407898 -0.395554
# 2018-01-08   -0.344426      -0.344426  -1.070694  2.451593 -0.395554
# 2018-01-10    0.113910       0.113910  -1.192100 -0.407898 -0.395554
# 2018-01-11   -0.344426      -0.344426  -1.192100 -0.407898 -0.395554
# 2018-01-12   -0.344426      -0.344426  -1.070694 -0.407898 -0.395554
# 2018-01-14   -0.344426      -0.344426  -1.070694 -0.407898 -0.395554
# 2018-01-15    0.572246       0.572246  -1.070694  2.451593 -0.395554
# 2018-01-16    0.113910       0.113910  -1.070694 -0.407898  2.528103
# 2018-01-17    1.030579       1.030579  -1.070694 -0.407898 -0.395554
# 2018-01-18   -0.344426      -0.344426  -1.313506 -0.407898 -0.395554
# 2018-01-19   -0.344426      -0.344426  -1.313506 -0.407898 -0.395554
# 2018-01-20    0.113910       0.113910  -1.313506 -0.407898 -0.395554
# 2018-01-22   -0.344426      -0.344426  -1.313506  2.451593 -0.395554
# 2018-01-23    0.572246       0.572246  -1.192100 -0.407898  2.528103
# 2018-01-24    0.113910       0.113910  -1.313506 -0.407898 -0.395554
# 2018-01-25   -0.344426      -0.344426  -1.192100 -0.407898 -0.395554
# 2018-01-26    0.113910       0.113910  -1.192100 -0.407898 -0.395554
# 2018-01-27    0.113910       0.113910  -1.313506 -0.407898 -0.395554
# 2018-01-28    0.113910       0.113910  -1.192100 -0.407898 -0.395554
# 2018-01-29    0.113910       0.113910  -1.192100  2.451593 -0.395554
# 2018-01-30    0.572246       0.572246  -1.192100 -0.407898  2.528103
# 2018-01-31    0.113910       0.113910  -1.192100 -0.407898 -0.395554
# 2018-02-01    0.113910       0.113910  -1.070694 -0.407898 -0.395554
# 2018-02-02   -0.344426      -0.344426  -1.070694 -0.407898 -0.395554
# 2018-02-04    1.947251       1.947251  -1.192100 -0.407898 -0.395554
# ...                ...            ...        ...       ...       ...
# 2018-04-26   -0.344426      -0.344426  -1.677725 -0.407898 -0.395554
# 2018-04-27   -0.344426      -0.344426  -1.677725 -0.407898 -0.395554
# 2018-04-28    0.113910       0.113910  -1.677725 -0.407898 -0.395554
# 2018-04-29   -0.344426      -0.344426  -1.920537 -0.407898 -0.395554
# 2018-05-02   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-03   -0.344426      -0.344426  -1.677725 -0.407898 -0.395554
# 2018-05-04   -0.344426      -0.344426  -1.556319 -0.407898 -0.395554
# 2018-05-05   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-06   -0.344426      -0.344426  -1.677725 -0.407898 -0.395554
# 2018-05-07    0.113910       0.113910  -1.434913  2.451593 -0.395554
# 2018-05-08   -0.344426      -0.344426  -1.677725 -0.407898  2.528103
# 2018-05-09   -0.344426      -0.344426  -1.920537 -0.407898 -0.395554
# 2018-05-10   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-11   -0.344426      -0.344426  -1.677725 -0.407898 -0.395554
# 2018-05-13    0.113910       0.113910  -2.163349 -0.407898 -0.395554
# 2018-05-14    0.113910       0.113910  -2.163349  2.451593 -0.395554
# 2018-05-15   -0.344426      -0.344426  -2.041943 -0.407898  2.528103
# 2018-05-17   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-18   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-19    0.113910       0.113910  -1.920537 -0.407898 -0.395554
# 2018-05-21   -0.344426      -0.344426  -1.799131  2.451593 -0.395554
# 2018-05-22    0.572246       0.572246  -1.920537 -0.407898  2.528103
# 2018-05-23   -0.344426      -0.344426  -1.920537 -0.407898 -0.395554
# 2018-05-24   -0.344426      -0.344426  -2.041943 -0.407898 -0.395554
# 2018-05-25    0.113910       0.113910  -1.920537 -0.407898 -0.395554
# 2018-05-26   -0.344426      -0.344426  -1.799131 -0.407898 -0.395554
# 2018-05-27   -0.344426      -0.344426  -2.163349 -0.407898 -0.395554
# 2018-05-28    0.113910       0.113910  -1.920537  2.451593 -0.395554
# 2018-05-30   -0.344426      -0.344426  -2.284755 -0.407898 -0.395554
# 2018-05-31   -0.344426      -0.344426  -2.041943 -0.407898 -0.395554
#
#             Wednesday  Thursday    Friday  Saturday    Sunday   Weekend
# datum
# 2018-01-02  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-03   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-04  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-05  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-01-06  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-01-07  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-01-08  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-10   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-11  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-12  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-01-14  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-01-15  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-16  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-17   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-18  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-19  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-01-20  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-01-22  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-23  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-24   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-25  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-26  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-01-27  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-01-28  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-01-29  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-30  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-01-31   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-02-01  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-02-02  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-02-04  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# ...               ...       ...       ...       ...       ...       ...
# 2018-04-26  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-04-27  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-04-28  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-04-29  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-05-02   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-03  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-04  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-05-05  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-05-06  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-05-07  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-08  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-09   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-10  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-11  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-05-13  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-05-14  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-15  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-17  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-18  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-05-19  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-05-21  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-22  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-23   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-24  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-25  -0.407898 -0.415227  2.408319 -0.407898 -0.407898 -0.631805
# 2018-05-26  -0.407898 -0.415227 -0.415227  2.451593 -0.407898  1.582768
# 2018-05-27  -0.407898 -0.415227 -0.415227 -0.407898  2.451593  1.582768
# 2018-05-28  -0.407898 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-30   2.451593 -0.415227 -0.415227 -0.407898 -0.407898 -0.631805
# 2018-05-31  -0.407898  2.408319 -0.415227 -0.407898 -0.407898 -0.631805
#
# [121 rows x 11 columns]

# %%
y_57_test_predicted = model_57.predict(X_57_test)

# %%
mae_57_test = mean_absolute_error(y_57_test, y_57_test_predicted)
mae_57_test
# Out:
# 40.01825760146925

# %%
mse_57_test = mean_squared_error(y_57_test, y_57_test_predicted)
mse_57_test
# Out:
# 4068.486420246041

# %%
rmse_57_test = np.sqrt(mean_squared_error(y_57_test, y_57_test_predicted))
rmse_57_test
# Out:
# 63.78468797639478

# %%
koeficijenti_57 = model_57.coef_
print(koeficijenti_57)
# Out:
# [-3.79391393e+13  3.79391393e+13 -2.52014160e+00 -3.49313916e+13
#  -3.41647557e+13 -3.49313916e+13 -3.53760827e+13 -3.53760827e+13
#   3.35775409e+14  3.35775409e+14 -4.78662503e+14]

# %%
odsjecak_57 = model_57.intercept_
print(odsjecak_57)
# Out:
# 58.59802480658444

# %%
paramtetri_nagiba_57 = model_57.get_params
print(paramtetri_nagiba_57)
# Out:
# <bound method BaseEstimator.get_params of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)>

# %%
y_57_test_predicted[0:5]
# Out:
# array([58.91052481, 60.66052481, 79.16052481, 77.66052481, 62.97302481])

# %%
y_57_test[:10]
# Out:
# datum
# 2018-01-02     26.0
# 2018-01-03     24.0
# 2018-01-04     28.0
# 2018-01-05    212.0
# 2018-01-06     72.0
# 2018-01-07     12.0
# 2018-01-08     19.0
# 2018-01-10     49.0
# 2018-01-11     95.0
# 2018-01-12    142.0
# Name: kol, dtype: float64

# %%
y_57_test_predicted[:10]
# Out:
# array([58.91052481, 60.66052481, 79.16052481, 77.66052481, 62.97302481,
#        39.34802481, 66.16052481, 55.53552481, 84.28552481, 77.34802481])

# %%
plt.scatter(y_57_test, y_57_test_predicted)
plt.xlabel("stvarne kolicina")
plt.ylabel("predviđene kolicina")
# Out:
# Text(0, 0.5, 'predviđene kolicina')

# %%
r2_score(y_57_test,y_57_test_predicted)
# Out:
# 0.1418527145615328

# %%
rmse_57_test = np.sqrt(mean_squared_error(y_57_test, y_57_test_predicted))
rmse_57_test
# Out:
# 63.78468797639478

# %%
pomocna_train = X_57_train['redna_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['redna_cena'].values.reshape(-1,1))  
X_57_train['redna_cena'] = pomocna_train

pomocna_test = X_57_test['redna_cena']
pomocna_test = std_scaler.transform(X_57_test['redna_cena'].values.reshape(-1,1))  
X_57_test['redna_cena'] = pomocna_test

pomocna_train = X_57_train['akcijska_cena']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['akcijska_cena'].values.reshape(-1,1))  
X_57_train['akcijska_cena'] = pomocna_train

pomocna_test = X_57_test['akcijska_cena']
pomocna_test = std_scaler.transform(X_57_test['akcijska_cena'].values.reshape(-1,1))  
X_57_test['akcijska_cena'] = pomocna_test

pomocna_train = X_57_train['n_trgovin']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['n_trgovin'].values.reshape(-1,1))  
X_57_train['n_trgovin'] = pomocna_train

pomocna_test = X_57_test['n_trgovin']
pomocna_test = std_scaler.transform(X_57_test['n_trgovin'].values.reshape(-1,1))  
X_57_test['n_trgovin'] = pomocna_test

pomocna_train = X_57_train['Monday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Monday'].values.reshape(-1,1))  
X_57_train['Monday'] = pomocna_train

pomocna_test = X_57_test['Monday']
pomocna_test = std_scaler.transform(X_57_test['Monday'].values.reshape(-1,1))  
X_57_test['Monday'] = pomocna_test

pomocna_train = X_57_train['Tuesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Tuesday'].values.reshape(-1,1))  
X_57_train['Tuesday'] = pomocna_train

pomocna_test = X_57_test['Tuesday']
pomocna_test = std_scaler.transform(X_57_test['Tuesday'].values.reshape(-1,1))  
X_57_test['Tuesday'] = pomocna_test

pomocna_train = X_57_train['Wednesday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Wednesday'].values.reshape(-1,1))  
X_57_train['Wednesday'] = pomocna_train

pomocna_test = X_57_test['Wednesday']
pomocna_test = std_scaler.transform(X_57_test['Wednesday'].values.reshape(-1,1))  
X_57_test['Wednesday'] = pomocna_test

pomocna_train = X_57_train['Thursday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Thursday'].values.reshape(-1,1))  
X_57_train['Thursday'] = pomocna_train

pomocna_test = X_57_test['Thursday']
pomocna_test = std_scaler.transform(X_57_test['Thursday'].values.reshape(-1,1))  
X_57_test['Thursday'] = pomocna_test

pomocna_train = X_57_train['Friday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Friday'].values.reshape(-1,1))  
X_57_train['Friday'] = pomocna_train

pomocna_test = X_57_test['Friday']
pomocna_test = std_scaler.transform(X_57_test['Friday'].values.reshape(-1,1))  
X_57_test['Friday'] = pomocna_test

pomocna_train = X_57_train['Saturday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Saturday'].values.reshape(-1,1))  
X_57_train['Saturday'] = pomocna_train

pomocna_test = X_57_test['Saturday']
pomocna_test = std_scaler.transform(X_57_test['Saturday'].values.reshape(-1,1))  
X_57_test['Saturday'] = pomocna_test

pomocna_train = X_57_train['Sunday']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Sunday'].values.reshape(-1,1))  
X_57_train['Sunday'] = pomocna_train

pomocna_test = X_57_test['Sunday']
pomocna_test = std_scaler.transform(X_57_test['Sunday'].values.reshape(-1,1))  
X_57_test['Sunday'] = pomocna_test

pomocna_train = X_57_train['Weekend']
std_scaler.fit(pomocna_train.values.reshape(-1,1))
pomocna_train = std_scaler.transform(X_57_train['Weekend'].values.reshape(-1,1))  
X_57_train['Weekend'] = pomocna_train

pomocna_test = X_57_test['Weekend']
pomocna_test = std_scaler.transform(X_57_test['Weekend'].values.reshape(-1,1))  
X_57_test['Weekend'] = pomocna_test

# %% [markdown]
# ### One Hot Encoding

# %%
tablica = X
tablica['day_of_week'] = tablica.index.get_level_values('datum').day_name()

# %%
encoded_columns = pd.get_dummies('day_of_week')

# %%
tablica.head()
# Out:
#                 redna_cena  akcijska_cena  n_trgovin    kol  Monday  Tuesday  \
# art datum
# 38  2016-01-02         0.1            0.1        439  769.0       0        0
#     2016-01-03         0.1            0.1        436  100.0       0        0
#     2016-01-04         0.1            0.1        441  305.0       1        0
#     2016-01-05         0.1            0.1        441   79.0       0        1
#     2016-01-06         0.1            0.1        444  344.0       0        0
#
#                 Wednesday  Thursday  Friday  Saturday  Sunday  Weekend  \
# art datum
# 38  2016-01-02          0         0       0         1       0        1
#     2016-01-03          0         0       0         0       1        1
#     2016-01-04          0         0       0         0       0        0
#     2016-01-05          0         0       0         0       0        0
#     2016-01-06          1         0       0         0       0        0
#
#                day_of_week
# art datum
# 38  2016-01-02    Saturday
#     2016-01-03      Sunday
#     2016-01-04      Monday
#     2016-01-05     Tuesday
#     2016-01-06   Wednesday

# %%
encoded_columns
# Out:
#    day_of_week
# 0            1

# %%
tablica = pd.merge(tablica, encoded_columns, on=['datum'], how='inner')
#tablica = tablica.join(encoded_columns)
# Out:
# ---------------------------------------------------
# KeyError          Traceback (most recent call last)
# <ipython-input-175-de9580862179> in <module>
# ----> 1 tablica = pd.merge(tablica, encoded_columns, on=['datum'], how='inner')
#       2 #tablica = tablica.join(encoded_columns)
#
# ~\AppData\Local\Continuum\miniconda3\envs\okolina\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~\AppData\Local\Continuum\miniconda3\envs\okolina\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# ~\AppData\Local\Continuum\miniconda3\envs\okolina\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     831                         if rk is not None:
#     832                             right_keys.append(
# --> 833                                 right._get_label_or_level_values(rk))
#     834                         else:
#     835                             # work-around for merge_asof(right_index=True)
#
# ~\AppData\Local\Continuum\miniconda3\envs\okolina\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 